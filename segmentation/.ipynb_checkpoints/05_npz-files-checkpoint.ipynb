# %% [markdown]
# # .npz files from patchlets
#
# - Creation of .npz files from the previous patchlets generated by 04_sampling

# %%
import os

print(os.getcwd())
# Out:
# /data/lscalambrin/proyecto_integrador/segmentation

# %%
import os

import numpy as np
import pandas as pd 
from tqdm.auto import tqdm

from functools import partial 
from concurrent.futures import ProcessPoolExecutor

from fd.utils import prepare_filesystem, multiprocess
from fd.create_npz_files import (
    CreateNpzConfig, 
    extract_npys, 
    concatenate_npys, 
    save_into_chunks
)

# %%
save_patch = '/data/lscalambrin/proyecto_integrador/segmentation/pergamino/eopatches'
save_patchlet = '/data/lscalambrin/proyecto_integrador/segmentation/pergamino/patchlets'
save_patchlet_npz = '/data/lscalambrin/proyecto_integrador/segmentation/pergamino/patchlets_npz'
df_path = '/data/lscalambrin/proyecto_integrador/segmentation/pergamino/patchlet-info.csv'

config = CreateNpzConfig(
    bucket_name='bucket-name',
    aws_access_key_id='',
    aws_secret_access_key='',
    aws_region='eu-central-1', 
    patchlets_folder=save_patchlet,
    output_folder=save_patchlet_npz, 
    output_dataframe=df_path,
    chunk_size=50)
# Out:
# /home/lscalambrin/miniconda3/envs/deep_crop/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# ### List of availables patchlets.

# %%
patchlets = [os.path.join(config.patchlets_folder, eop_name)
             for eop_name in os.listdir(config.patchlets_folder)]

# %%
len(patchlets)
# Out:
# 498

# %%
partial_fn = partial(extract_npys, cfg=config)

# %%
npys = multiprocess(partial_fn, patchlets, max_workers=24)
# Out:
#   0%|          | 0/498 [00:00<?, ?it/s]

# %%
npys_dict = concatenate_npys(npys)

# %%
npys_dict.keys()
# Out:
# dict_keys(['X', 'y_boundary', 'y_extent', 'y_distance', 'timestamps', 'eop_names'])

# %%
save_into_chunks(config, npys_dict)

# %% [markdown]
# #### Check that results make sense

# %%
npzs = os.listdir(config.output_folder)

# %%
len(npzs)
# Out:
# 114

# %% [markdown]
# ### Reading an npz for testing

# %%
test_npz = np.load(open(os.path.join(config.output_folder, npzs[0]), 'rb'), 
                   allow_pickle=True)

# %% [markdown]
# #### chunk_size=50
# Each chunk has 50 elements to train the net. These elements correspond to different eopatches and differents dates. See example "df.head"

# %%
test_npz['X'].shape, test_npz['y_extent'].shape, test_npz['timestamps'].shape
# Out:
# ((50, 256, 256, 4), (50, 256, 256, 1), (50,))

# %%
df = pd.read_csv(open(config.output_dataframe))

# %%
df.head(52)
# Out:
#                                 chunk     eopatch  \
# 0   patchlets_field_delineation_0.npz  eopatch_15
# 1   patchlets_field_delineation_0.npz  eopatch_15
# 2   patchlets_field_delineation_0.npz  eopatch_15
# 3   patchlets_field_delineation_0.npz  eopatch_15
# 4   patchlets_field_delineation_0.npz  eopatch_15
# 5   patchlets_field_delineation_0.npz  eopatch_15
# 6   patchlets_field_delineation_0.npz  eopatch_15
# 7   patchlets_field_delineation_0.npz  eopatch_15
# 8   patchlets_field_delineation_0.npz  eopatch_15
# 9   patchlets_field_delineation_0.npz  eopatch_15
# 10  patchlets_field_delineation_0.npz  eopatch_15
# 11  patchlets_field_delineation_0.npz  eopatch_13
# 12  patchlets_field_delineation_0.npz  eopatch_13
# 13  patchlets_field_delineation_0.npz  eopatch_13
# 14  patchlets_field_delineation_0.npz  eopatch_13
# 15  patchlets_field_delineation_0.npz  eopatch_13
# 16  patchlets_field_delineation_0.npz  eopatch_13
# 17  patchlets_field_delineation_0.npz  eopatch_13
# 18  patchlets_field_delineation_0.npz  eopatch_13
# 19  patchlets_field_delineation_0.npz  eopatch_13
# 20  patchlets_field_delineation_0.npz  eopatch_13
# 21  patchlets_field_delineation_0.npz  eopatch_13
# 22  patchlets_field_delineation_0.npz   eopatch_7
# 23  patchlets_field_delineation_0.npz   eopatch_7
# 24  patchlets_field_delineation_0.npz   eopatch_7
# 25  patchlets_field_delineation_0.npz   eopatch_7
# 26  patchlets_field_delineation_0.npz   eopatch_7
# 27  patchlets_field_delineation_0.npz   eopatch_7
# 28  patchlets_field_delineation_0.npz   eopatch_7
# 29  patchlets_field_delineation_0.npz   eopatch_7
# 30  patchlets_field_delineation_0.npz   eopatch_7
# 31  patchlets_field_delineation_0.npz   eopatch_7
# 32  patchlets_field_delineation_0.npz   eopatch_7
# 33  patchlets_field_delineation_0.npz   eopatch_7
# 34  patchlets_field_delineation_0.npz  eopatch_25
# 35  patchlets_field_delineation_0.npz  eopatch_25
# 36  patchlets_field_delineation_0.npz  eopatch_25
# 37  patchlets_field_delineation_0.npz  eopatch_25
# 38  patchlets_field_delineation_0.npz  eopatch_25
# 39  patchlets_field_delineation_0.npz  eopatch_25
# 40  patchlets_field_delineation_0.npz  eopatch_25
# 41  patchlets_field_delineation_0.npz  eopatch_25
# 42  patchlets_field_delineation_0.npz  eopatch_25
# 43  patchlets_field_delineation_0.npz  eopatch_25
# 44  patchlets_field_delineation_0.npz   eopatch_5
# 45  patchlets_field_delineation_0.npz   eopatch_5
# 46  patchlets_field_delineation_0.npz   eopatch_5
# 47  patchlets_field_delineation_0.npz   eopatch_5
# 48  patchlets_field_delineation_0.npz   eopatch_5
# 49  patchlets_field_delineation_0.npz   eopatch_5
# 50  patchlets_field_delineation_1.npz   eopatch_5
# 51  patchlets_field_delineation_1.npz   eopatch_5
#
#                                              patchlet  chunk_pos  \
# 0   /data/lscalambrin/proyecto_integrador/segmenta...          0
# 1   /data/lscalambrin/proyecto_integrador/segmenta...          1
# 2   /data/lscalambrin/proyecto_integrador/segmenta...          2
# 3   /data/lscalambrin/proyecto_integrador/segmenta...          3
# 4   /data/lscalambrin/proyecto_integrador/segmenta...          4
# 5   /data/lscalambrin/proyecto_integrador/segmenta...          5
# 6   /data/lscalambrin/proyecto_integrador/segmenta...          6
# 7   /data/lscalambrin/proyecto_integrador/segmenta...          7
# 8   /data/lscalambrin/proyecto_integrador/segmenta...          8
# 9   /data/lscalambrin/proyecto_integrador/segmenta...          9
# 10  /data/lscalambrin/proyecto_integrador/segmenta...         10
# 11  /data/lscalambrin/proyecto_integrador/segmenta...         11
# 12  /data/lscalambrin/proyecto_integrador/segmenta...         12
# 13  /data/lscalambrin/proyecto_integrador/segmenta...         13
# 14  /data/lscalambrin/proyecto_integrador/segmenta...         14
# 15  /data/lscalambrin/proyecto_integrador/segmenta...         15
# 16  /data/lscalambrin/proyecto_integrador/segmenta...         16
# 17  /data/lscalambrin/proyecto_integrador/segmenta...         17
# 18  /data/lscalambrin/proyecto_integrador/segmenta...         18
# 19  /data/lscalambrin/proyecto_integrador/segmenta...         19
# 20  /data/lscalambrin/proyecto_integrador/segmenta...         20
# 21  /data/lscalambrin/proyecto_integrador/segmenta...         21
# 22  /data/lscalambrin/proyecto_integrador/segmenta...         22
# 23  /data/lscalambrin/proyecto_integrador/segmenta...         23
# 24  /data/lscalambrin/proyecto_integrador/segmenta...         24
# 25  /data/lscalambrin/proyecto_integrador/segmenta...         25
# 26  /data/lscalambrin/proyecto_integrador/segmenta...         26
# 27  /data/lscalambrin/proyecto_integrador/segmenta...         27
# 28  /data/lscalambrin/proyecto_integrador/segmenta...         28
# 29  /data/lscalambrin/proyecto_integrador/segmenta...         29
# 30  /data/lscalambrin/proyecto_integrador/segmenta...         30
# 31  /data/lscalambrin/proyecto_integrador/segmenta...         31
# 32  /data/lscalambrin/proyecto_integrador/segmenta...         32
# 33  /data/lscalambrin/proyecto_integrador/segmenta...         33
# 34  /data/lscalambrin/proyecto_integrador/segmenta...         34
# 35  /data/lscalambrin/proyecto_integrador/segmenta...         35
# 36  /data/lscalambrin/proyecto_integrador/segmenta...         36
# 37  /data/lscalambrin/proyecto_integrador/segmenta...         37
# 38  /data/lscalambrin/proyecto_integrador/segmenta...         38
# 39  /data/lscalambrin/proyecto_integrador/segmenta...         39
# 40  /data/lscalambrin/proyecto_integrador/segmenta...         40
# 41  /data/lscalambrin/proyecto_integrador/segmenta...         41
# 42  /data/lscalambrin/proyecto_integrador/segmenta...         42
# 43  /data/lscalambrin/proyecto_integrador/segmenta...         43
# 44  /data/lscalambrin/proyecto_integrador/segmenta...         44
# 45  /data/lscalambrin/proyecto_integrador/segmenta...         45
# 46  /data/lscalambrin/proyecto_integrador/segmenta...         46
# 47  /data/lscalambrin/proyecto_integrador/segmenta...         47
# 48  /data/lscalambrin/proyecto_integrador/segmenta...         48
# 49  /data/lscalambrin/proyecto_integrador/segmenta...         49
# 50  /data/lscalambrin/proyecto_integrador/segmenta...          0
# 51  /data/lscalambrin/proyecto_integrador/segmenta...          1
#
#               timestamp
# 0   2017-09-19 14:00:39
# 1   2017-10-14 14:00:51
# 2   2017-11-23 14:00:51
# 3   2017-11-28 14:00:39
# 4   2017-12-18 14:00:39
# 5   2017-12-28 14:00:39
# 6   2018-01-07 14:00:49
# 7   2018-01-22 14:00:51
# 8   2018-03-03 14:00:51
# 9   2018-03-13 14:00:51
# 10  2018-03-23 14:00:51
# 11  2017-09-19 14:00:39
# 12  2017-10-14 14:00:51
# 13  2017-11-23 14:00:51
# 14  2017-11-28 14:00:39
# 15  2017-12-18 14:00:39
# 16  2017-12-28 14:00:39
# 17  2018-01-07 14:00:49
# 18  2018-01-22 14:00:51
# 19  2018-03-03 14:00:51
# 20  2018-03-13 14:00:51
# 21  2018-03-23 14:00:51
# 22  2017-09-19 14:00:39
# 23  2017-10-14 14:00:51
# 24  2017-11-23 14:00:51
# 25  2017-11-28 14:00:39
# 26  2017-12-18 14:00:39
# 27  2017-12-28 14:00:39
# 28  2018-01-07 14:00:49
# 29  2018-01-22 14:00:51
# 30  2018-02-06 14:00:49
# 31  2018-03-03 14:00:51
# 32  2018-03-13 14:00:51
# 33  2018-03-23 14:00:51
# 34  2017-09-19 14:00:39
# 35  2017-10-14 14:00:51
# 36  2017-11-23 14:00:51
# 37  2017-11-28 14:00:39
# 38  2017-12-18 14:00:39
# 39  2017-12-28 14:00:39
# 40  2018-01-07 14:00:49
# 41  2018-01-22 14:00:51
# 42  2018-03-13 14:00:51
# 43  2018-03-23 14:00:51
# 44  2017-09-19 14:00:39
# 45  2017-10-14 14:00:51
# 46  2017-11-23 14:00:51
# 47  2017-11-28 14:00:39
# 48  2017-12-18 14:00:39
# 49  2017-12-28 14:00:39
# 50  2018-01-07 14:00:49
# 51  2018-01-22 14:00:51

# %%
len(df)
# Out:
# /home/lscalambrin/miniconda3/envs/deep_crop/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 5670
